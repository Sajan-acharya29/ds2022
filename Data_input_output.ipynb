# %%
! pip install beautifulSoup4

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list")

# %%
df[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
df = pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list")

# %%
df[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [54], in <cell line: 1>()
# ----> 1 df.columns
#
# AttributeError: 'list' object has no attribute 'columns'

# %% [markdown]
# * # CSV Input

# %%
df = df[0]
df.head()
# Out:
#                       Bank NameBank           CityCity StateSt  CertCert  \
# 0                 Almena State Bank             Almena      KS     15426
# 1        First City Bank of Florida  Fort Walton Beach      FL     16748
# 2              The First State Bank      Barboursville      WV     14361
# 3                Ericson State Bank            Ericson      NE     18265
# 4  City National Bank of New Jersey             Newark      NJ     21111
#
#       Acquiring InstitutionAI Closing DateClosing  FundFund
# 0                 Equity Bank    October 23, 2020     10538
# 1   United Fidelity Bank, fsb    October 16, 2020     10537
# 2              MVB Bank, Inc.       April 3, 2020     10536
# 3  Farmers and Merchants Bank   February 14, 2020     10535
# 4             Industrial Bank    November 1, 2019     10534

# %%
#Saving as csv file

df.to_csv("test_csv_file", index = False)

#created a test_csv_file at the folder
df.columns       # to get the nuames of columns
# Out:
# Index(['Bank NameBank', 'CityCity', 'StateSt', 'CertCert',
#        'Acquiring InstitutionAI', 'Closing DateClosing', 'FundFund'],
#       dtype='object')

# %%
df = pd.read_csv("test_csv_file")
df
df.info()               #to get the more infomration about your data from columns

new_columns = (['NameBank', 'City', 'State', 'Cert',
       'Acquiring InstitutionAI', 'DateClosing', 'Fund'])
df.columns = new_columns
df.columns
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563 entries, 0 to 562
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Bank NameBank            563 non-null    object
#  1   CityCity                 563 non-null    object
#  2   StateSt                  563 non-null    object
#  3   CertCert                 563 non-null    int64
#  4   Acquiring InstitutionAI  563 non-null    object
#  5   Closing DateClosing      563 non-null    object
#  6   FundFund                 563 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 30.9+ KB
#                      NameBank               City State   Cert  \
# 0           Almena State Bank             Almena    KS  15426
# 1  First City Bank of Florida  Fort Walton Beach    FL  16748
#
#      Acquiring InstitutionAI       DateClosing   Fund
# 0                Equity Bank  October 23, 2020  10538
# ...

# %%
df['DateClosing'].dtypes
# Out:
# dtype('O')

# %%
df['New_DateClosing'] = pd.to_datetime(df['DateClosing'])
df.head(2)
# Out:
#                      NameBank               City State   Cert  \
# 0           Almena State Bank             Almena    KS  15426
# 1  First City Bank of Florida  Fort Walton Beach    FL  16748
#
#      Acquiring InstitutionAI       DateClosing   Fund New_DateClosing
# 0                Equity Bank  October 23, 2020  10538      2020-10-23
# 1  United Fidelity Bank, fsb  October 16, 2020  10537      2020-10-16

# %%
df.drop('DateClosing', axis=1, inplace = True)

# %%
df.head(2)
# Out:
#                      NameBank               City State   Cert  \
# 0           Almena State Bank             Almena    KS  15426
# 1  First City Bank of Florida  Fort Walton Beach    FL  16748
#
#      Acquiring InstitutionAI   Fund New_DateClosing
# 0                Equity Bank  10538      2020-10-23
# 1  United Fidelity Bank, fsb  10537      2020-10-16

# %%
df['New_DateClosing'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
#converting the datetime object to a string

df['New_DateClosing'] = df['New_DateClosing'].astype('string')

# %%
df['New_DateClosing'].dtypes
# Out:
# StringDtype

# %%
df['year']= df['New_DateClosing'].apply(lambda x: x.split('-')[0])
df['month']= df['New_DateClosing'].apply(lambda x: x.split('-')[1])
df['date']= df['New_DateClosing'].apply(lambda x: x.split('-')[2])

# %%
df.head()
# Out:
#                            NameBank               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#       Acquiring InstitutionAI   Fund New_DateClosing  year month date
# 0                 Equity Bank  10538      2020-10-23  2020    10   23
# 1   United Fidelity Bank, fsb  10537      2020-10-16  2020    10   16
# 2              MVB Bank, Inc.  10536      2020-04-03  2020    04   03
# 3  Farmers and Merchants Bank  10535      2020-02-14  2020    02   14
# 4             Industrial Bank  10534      2019-11-01  2019    11   01

# %%
df.columns
# Out:
# Index(['NameBank', 'City', 'State', 'Cert', 'Acquiring InstitutionAI', 'Fund',
#        'New_DateClosing', 'year', 'month', 'date'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
#none means all the columns . Meaning unlimited

# %%
df.head()
# Out:
#                            NameBank               City State   Cert  \
# 0                 Almena State Bank             Almena    KS  15426
# 1        First City Bank of Florida  Fort Walton Beach    FL  16748
# 2              The First State Bank      Barboursville    WV  14361
# 3                Ericson State Bank            Ericson    NE  18265
# 4  City National Bank of New Jersey             Newark    NJ  21111
#
#       Acquiring InstitutionAI   Fund New_DateClosing  year month date
# 0                 Equity Bank  10538      2020-10-23  2020    10   23
# 1   United Fidelity Bank, fsb  10537      2020-10-16  2020    10   16
# 2              MVB Bank, Inc.  10536      2020-04-03  2020    04   03
# 3  Farmers and Merchants Bank  10535      2020-02-14  2020    02   14
# 4             Industrial Bank  10534      2019-11-01  2019    11   01

# %%
df.drop('New_DateClosing', axis=1, inplace = True)

#axis = 1 because it is the column elseL: 0 for the row

# %%
df
# Out:
#                               NameBank               City State   Cert  \
# 0                    Almena State Bank             Almena    KS  15426
# 1           First City Bank of Florida  Fort Walton Beach    FL  16748
# 2                 The First State Bank      Barboursville    WV  14361
# 3                   Ericson State Bank            Ericson    NE  18265
# 4     City National Bank of New Jersey             Newark    NJ  21111
# ..                                 ...                ...   ...    ...
# 558                 Superior Bank, FSB           Hinsdale    IL  32646
# 559                Malta National Bank              Malta    OH   6629
# 560    First Alliance Bank & Trust Co.         Manchester    NH  34264
# 561  National State Bank of Metropolis         Metropolis    IL   3815
# 562                   Bank of Honolulu           Honolulu    HI  21029
#
#                  Acquiring InstitutionAI   Fund  year month date
# ...

# %%
for ind, row in df.iterrows():
    print(row['State'])
    print(ind, "1")
# Out:
# KS
# 0 1
# FL
# 1 1
# WV
# 2 1
# NE
# 3 1
# NJ
# 4 1
# OH
# 5 1
# KY
# 6 1
# TX
# 7 1
# IL
# 8 1
# KS
# 9 1
# IL
# 10 1
# WI
# 11 1
# LA
# 12 1
# UT
# 13 1
# IL
# 14 1
# NJ
# 15 1
# AR
# 16 1
# GA
# 17 1
# PA
# 18 1
# TN
# 19 1
# WI
# 20 1
# WA
# 21 1
# GA
# 22 1
# CO
# 23 1
# IL
# 24 1
# PR
# 25 1
# GA
# 26 1
# IL
# 27 1
# FL
# 28 1
# MN
# 29 1
# CA
# 30 1
# IL
# 31 1
# MD
# 32 1
# IL
# 33 1
# GA
# 34 1
# OK
# 35 1
# FL
# 36 1
# IL
# 37 1
# MD
# 38 1
# OH
# 39 1
# IL
# 40 1
# SC
# 41 1
# PA
# 42 1
# VA
# 43 1
# ID
# 44 1
# OK
# 45 1
# IL
# 46 1
# TX
# 47 1
# FL
# 48 1
# TX
# 49 1
# CT
# 50 1
# AZ
# 51 1
# TN
# 52 1
# WI
# 53 1
# FL
# 54 1
# TN
# 55 1
# NV
# 56 1
# WI
# 57 1
# AZ
# 58 1
# GA
# 59 1
# NC
# 60 1
# GA
# 61 1
# NC
# 62 1
# FL
# 63 1
# FL
# 64 1
# KY
# 65 1
# AZ
# 66 1
# GA
# 67 1
# IL
# 68 1
# MN
# 69 1
# WA
# 70 1
# MO
# 71 1
# GA
# 72 1
# IL
# 73 1
# FL
# 74 1
# PA
# 75 1
# MO
# 76 1
# FL
# 77 1
# FL
# 78 1
# IL
# 79 1
# MO
# 80 1
# MN
# 81 1
# IL
# 82 1
# GA
# 83 1
# ...

# %% [markdown]
# * # groupby method

# %%
group_df = df.groupby(["State", "Fund"])

# %%
group_df.mean()
# Out:
#               Cert
# State Fund
# AL    10103   9609
#       10106  22130
#       10163  32276
#       10204  24957
#       10356  19794
# ...            ...
# WI    10518  20364
#       10527  30003
# WV    10014   6782
#       10536  14361
# WY    10080  22754
#
# [563 rows x 1 columns]

# %%
group_df = df.groupby("Fund")
group_df["Fund"].mean()
# Out:
# Fund
# 4645      4645
# 4646      4646
# 4647      4647
# 4648      4648
# 4649      4649
#          ...
# 10534    10534
# 10535    10535
# 10536    10536
# 10537    10537
# 10538    10538
# Name: Fund, Length: 563, dtype: int64

# %%
#Split month, date, year.

# %% [markdown]
# * # Excel input and output

# %%
pd.read_excel("Excel_Sample.xlsx", sheet_name ="Sheet1")
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# * # Excel Output

# %%
df.to_excel("Excel_Sample.xlsx", sheet_name = "Excel_test")
